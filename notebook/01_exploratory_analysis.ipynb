# %% [markdown]
# # Análisis Exploratorio de los Datos

# %%
# Importamos librerías
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1. Cargar y visualizar los datos

# %%
df = pd.read_csv('../data/raw/social_media_vs_productivity.csv')
df
# Out:
#        age  gender    job_type  daily_social_media_time  \
# 0       56    Male  Unemployed                 4.180940
# 1       46    Male      Health                 3.249603
# 2       32    Male     Finance                      NaN
# 3       60  Female  Unemployed                      NaN
# 4       25    Male          IT                      NaN
# ...    ...     ...         ...                      ...
# 29995   34  Female      Health                 1.877297
# 29996   39    Male      Health                 4.437784
# 29997   42    Male   Education                17.724981
# 29998   20  Female   Education                 3.796634
# 29999   44    Male  Unemployed                      NaN
#
#       social_platform_preference  number_of_notifications  work_hours_per_day  \
# 0                       Facebook                       61            6.753558
# 1                        Twitter                       59            9.169296
# ...

# %% [markdown]
# ### 1.1 Vista general

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   age                             30000 non-null  int64
#  1   gender                          30000 non-null  object
#  2   job_type                        30000 non-null  object
#  3   daily_social_media_time         27235 non-null  float64
#  4   social_platform_preference      30000 non-null  object
#  5   number_of_notifications         30000 non-null  int64
#  6   work_hours_per_day              30000 non-null  float64
#  7   perceived_productivity_score    28386 non-null  float64
#  8   actual_productivity_score       27635 non-null  float64
#  9   stress_level                    28096 non-null  float64
#  10  sleep_hours                     27402 non-null  float64
#  11  screen_time_before_sleep        27789 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 age  daily_social_media_time  number_of_notifications  \
# count  30000.000000             27235.000000             30000.000000
# mean      41.486867                 3.113418                59.958767
# std       13.835221                 2.074813                 7.723772
# min       18.000000                 0.000000                30.000000
# 25%       30.000000                 1.639566                55.000000
# 50%       41.000000                 3.025913                60.000000
# 75%       53.000000                 4.368917                65.000000
# max       65.000000                17.973256                90.000000
#
#        work_hours_per_day  perceived_productivity_score  \
# count        30000.000000                  28386.000000
# mean             6.990792                      5.510488
# std              1.997736                      2.023470
# min              0.000000                      2.000252
# ...

# %% [markdown]
# ## 2. Evaluar la calidad de los datos

# %%
# Valores nulos
df_nulls = df.isnull().sum().reset_index()
df_nulls.rename(columns={0 : 'count'}, inplace = True)
df_nulls['count'] = (df_nulls['count'] / df_nulls['count'].sum() * 100).round(2)
df_nulls
# Out:
#                              index  count
# 0                              age   0.00
# 1                           gender   0.00
# 2                         job_type   0.00
# 3          daily_social_media_time  17.08
# 4       social_platform_preference   0.00
# 5          number_of_notifications   0.00
# 6               work_hours_per_day   0.00
# 7     perceived_productivity_score   9.97
# 8        actual_productivity_score  14.61
# 9                     stress_level  11.76
# 10                     sleep_hours  16.05
# 11        screen_time_before_sleep  13.66
# 12              breaks_during_work   0.00
# 13                 uses_focus_apps   0.00
# 14   has_digital_wellbeing_enabled   0.00
# 15      coffee_consumption_per_day   0.00
# 16  days_feeling_burnout_per_month   0.00
# 17            weekly_offline_hours   0.00
# 18          job_satisfaction_score  16.87

# %%
del df_nulls

# %%
# Valores duplicados
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## 3. Análisis univariado (una variable a la vez)

# %%
numeric_columns = df.select_dtypes('number').columns
category_columns = df.select_dtypes('object').columns

# %%
# Generación de histogramas para ver su distribución, asi como para poder ver la moda, mediana y su media
for column in numeric_columns:
    plt.figure(figsize=(12, 8))
    sns.histplot(data=df[column], color='green', alpha=0.7, kde=True)
    plt.axvline(df[column].mean(), color='red', linestyle='--', alpha=0.7)
    plt.axvline(df[column].median(), color='blue', linestyle='--', alpha=0.7)
    plt.title('Distribution of ' + column)
    plt.show()

# %%
# Generación de boxplots para identificar valores atípicos
for columns in numeric_columns:
    plt.figure(figsize=(8, 12))
    sns.boxplot(data=df[columns], color='green')
    plt.show()

# %%
# Generación de gráficos de barras para ver el conteo de valores únicos
for columns in category_columns:

    data = df[columns].value_counts().reset_index()

    plt.figure(figsize=(12, 8))
    sns.barplot(data=data, x=columns, y='count', color='green', alpha=.7)
    plt.show()

# %% [markdown]
# ## 4. Análisis bivariado (relaciones entre dos variables)

# %% [markdown]
# ### Numérica vs. Numérica

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(data=df[numeric_columns].corr(), annot=True, cmap='crest', fmt='.2f')
# Out:
# <Axes: >

# %%
sns.scatterplot(data=df, x='job_satisfaction_score', y='actual_productivity_score')
# Out:
# <Axes: xlabel='job_satisfaction_score', ylabel='actual_productivity_score'>

# %%
# Analizar si el uso de las redes sociales afecta a las horas que trabajan por día
sns.scatterplot(data=df, x='daily_social_media_time', y='work_hours_per_day')
df[['daily_social_media_time', 'work_hours_per_day']].corr().iloc[0, 1].round(3)
# Out:
# np.float64(-0.003)

# %%
# Analizar si el uso de las redes sociales afecta al consumo del café por día
sns.scatterplot(data=df, x='daily_social_media_time', y='coffee_consumption_per_day')
df[['daily_social_media_time', 'coffee_consumption_per_day']].corr().iloc[0, 1].round(3)
# Out:
# np.float64(-0.004)

# %%
# Analizar si el uso de las redes sociales afectan a las horas de sueño
sns.scatterplot(data=df, x='daily_social_media_time', y='sleep_hours')
df[['daily_social_media_time', 'sleep_hours']].corr().iloc[0, 1].round(3)
# Out:
# np.float64(0.012)

# %% [markdown]
# ### Categorical vs. Númerica

# %%
# Analizar si el tipo de trabajo está relacionado con la edad
df.groupby('job_type')['age'].mean().round()
# Out:
# job_type
# Education     42.0
# Finance       42.0
# Health        42.0
# IT            41.0
# Student       41.0
# Unemployed    41.0
# Name: age, dtype: float64

# %%
# Asi la plataforma está relacionada con el tiempo en pantalla
df.groupby('social_platform_preference')['daily_social_media_time'].sum().round().sort_values(ascending=False)
# Out:
# social_platform_preference
# TikTok       17536.0
# Facebook     16985.0
# Instagram    16837.0
# Twitter      16725.0
# Telegram     16711.0
# Name: daily_social_media_time, dtype: float64

# %%
# Analizar que genero toma más café
df.groupby('gender')['coffee_consumption_per_day'].sum().round()
# Out:
# gender
# Female    28846
# Male      28832
# Other      2301
# Name: coffee_consumption_per_day, dtype: int64

# %%
# Analizar si el tipo de trabajo tiene su propia satisfacción
df.groupby('job_type')['job_satisfaction_score'].mean().round(2).sort_values(ascending=False)
# Out:
# job_type
# IT            5.04
# Health        4.97
# Education     4.95
# Finance       4.95
# Unemployed    4.95
# Student       4.93
# Name: job_satisfaction_score, dtype: float64

# %%
# Analizar si las redes sociales influyen en la edad
df.groupby('social_platform_preference')['age'].mean().round().sort_values(ascending=False)
# Out:
# social_platform_preference
# Facebook     42.0
# TikTok       42.0
# Twitter      42.0
# Instagram    41.0
# Telegram     41.0
# Name: age, dtype: float64

# %%
# Analizar si el consumo del café tiene que ver con el tipo de trabajo
df.groupby('job_type')['coffee_consumption_per_day'].sum().round(2).sort_values(ascending=False)
# Out:
# job_type
# IT            10150
# Education     10130
# Finance       10091
# Student        9991
# Unemployed     9871
# Health         9746
# Name: coffee_consumption_per_day, dtype: int64

# %%
# Analizamos si el tipo de trabajo tiene relación con los niveles de estres
df.groupby('job_type')['stress_level'].sum().round(2).sort_values(ascending=False)
# Out:
# job_type
# Finance       26421.0
# Education     26177.0
# IT            25885.0
# Student       25710.0
# Unemployed    25427.0
# Health        25303.0
# Name: stress_level, dtype: float64

# %%
# Analizamos si el tipo de trabajo tiene que ver con la productividad
df.groupby('job_type')['actual_productivity_score'].mean().round(2).sort_values(ascending=False)
# Out:
# job_type
# IT            5.01
# Unemployed    4.99
# Finance       4.97
# Education     4.93
# Health        4.92
# Student       4.90
# Name: actual_productivity_score, dtype: float64
